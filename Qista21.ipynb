# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt 
import datetime as dt
import numpy as np

# %%
QistaAquitaine=pd.read_csv('Data/QistaAquitaine21.csv')

# %%
QistaIDF=pd.read_csv('Data/QistaIDF21.csv')

# %%
QistaOcci=pd.read_csv('Data/QistaOccitanie21.csv')

# %%
QistaPACA=pd.read_csv('Data/QistaPACA21.csv')

# %%
QistaRA=pd.read_csv('Data/QistaRA21.csv')

# %%
Qista21=pd.merge(QistaRA,QistaPACA, on='Semaine')

# %%
Qista21=pd.merge(Qista21,QistaOcci, on='Semaine')

# %%
Qista21=pd.merge(Qista21,QistaIDF, on='Semaine')

# %%
Qista21=pd.merge(Qista21,QistaAquitaine, on='Semaine')

# %%
ax=Qista21.plot(figsize=(20,12))

# %%
Qista21.rename(columns={'Semaine': 'Date'}, inplace=True)

# %%
Qista21
# Out:
#           Date  Rhone-Alpes  Provence-Alpes-Cote d'Azur  Occitanie  \
# 0   2021-01-03           30                           0          0
# 1   2021-01-10            0                           0          0
# 2   2021-01-17            0                           0          0
# 3   2021-01-24            0                           0          0
# 4   2021-01-31            0                           0          0
# 5   2021-02-07            0                           0          0
# 6   2021-02-14            0                           0          0
# 7   2021-02-21            0                           0          0
# 8   2021-02-28            0                           0          0
# 9   2021-03-07            0                           0          0
# 10  2021-03-14            0                           0          0
# 11  2021-03-21            0                           0          0
# 12  2021-03-28           31                           0          0
# ...

# %%
Qista21.groupby(by=["Date"], dropna=False).sum()
# Out:
#             Rhone-Alpes  Provence-Alpes-Cote d'Azur  Occitanie  Ile-de-France  \
# Date
# 2021-01-03           30                           0          0              0
# 2021-01-10            0                           0          0              0
# 2021-01-17            0                           0          0              0
# 2021-01-24            0                           0          0              0
# 2021-01-31            0                           0          0              0
# 2021-02-07            0                           0          0              0
# 2021-02-14            0                           0          0              0
# 2021-02-21            0                           0          0              0
# 2021-02-28            0                           0          0              0
# 2021-03-07            0                           0          0              0
# 2021-03-14            0                           0          0              0
# ...

# %%
Qista21['Date'].apply(lambda x: x.replace('-',' ').replace(' ',' ')).astype('datetime64')
# Out:
# 0    2021-01-03
# 1    2021-01-10
# 2    2021-01-17
# 3    2021-01-24
# 4    2021-01-31
# 5    2021-02-07
# 6    2021-02-14
# 7    2021-02-21
# 8    2021-02-28
# 9    2021-03-07
# 10   2021-03-14
# 11   2021-03-21
# 12   2021-03-28
# 13   2021-04-04
# 14   2021-04-11
# 15   2021-04-18
# 16   2021-04-25
# 17   2021-05-02
# 18   2021-05-09
# 19   2021-05-16
# 20   2021-05-23
# 21   2021-05-30
# 22   2021-06-06
# 23   2021-06-13
# 24   2021-06-20
# 25   2021-06-27
# 26   2021-07-04
# 27   2021-07-11
# 28   2021-07-18
# 29   2021-07-25
# 30   2021-08-01
# 31   2021-08-08
# 32   2021-08-15
# 33   2021-08-22
# 34   2021-08-29
# 35   2021-09-05
# 36   2021-09-12
# 37   2021-09-19
# 38   2021-09-26
# 39   2021-10-03
# 40   2021-10-10
# 41   2021-10-17
# 42   2021-10-24
# 43   2021-10-31
# 44   2021-11-07
# 45   2021-11-14
# 46   2021-11-21
# 47   2021-11-28
# 48   2021-12-05
# 49   2021-12-12
# 50   2021-12-19
# 51   2021-12-26
# Name: Date, dtype: datetime64[ns]

# %%
Qista21
# Out:
#           Date  Rhone-Alpes  Provence-Alpes-Cote d'Azur  Occitanie  \
# 0   2021-01-03           30                           0          0
# 1   2021-01-10            0                           0          0
# 2   2021-01-17            0                           0          0
# 3   2021-01-24            0                           0          0
# 4   2021-01-31            0                           0          0
# 5   2021-02-07            0                           0          0
# 6   2021-02-14            0                           0          0
# 7   2021-02-21            0                           0          0
# 8   2021-02-28            0                           0          0
# 9   2021-03-07            0                           0          0
# 10  2021-03-14            0                           0          0
# 11  2021-03-21            0                           0          0
# 12  2021-03-28           31                           0          0
# ...

# %%
#Qista21['Date']=pd.DatetimeIndex(Qista21['Date']).month

# %%
Qista21
# Out:
#           Date  Rhone-Alpes  Provence-Alpes-Cote d'Azur  Occitanie  \
# 0   2021-01-03           30                           0          0
# 1   2021-01-10            0                           0          0
# 2   2021-01-17            0                           0          0
# 3   2021-01-24            0                           0          0
# 4   2021-01-31            0                           0          0
# 5   2021-02-07            0                           0          0
# 6   2021-02-14            0                           0          0
# 7   2021-02-21            0                           0          0
# 8   2021-02-28            0                           0          0
# 9   2021-03-07            0                           0          0
# 10  2021-03-14            0                           0          0
# 11  2021-03-21            0                           0          0
# 12  2021-03-28           31                           0          0
# ...

# %%
Qista21= Qista21.groupby('Date').sum()

# %%
Qista21
# Out:
#             Rhone-Alpes  Provence-Alpes-Cote d'Azur  Occitanie  Ile-de-France  \
# Date
# 2021-01-03           30                           0          0              0
# 2021-01-10            0                           0          0              0
# 2021-01-17            0                           0          0              0
# 2021-01-24            0                           0          0              0
# 2021-01-31            0                           0          0              0
# 2021-02-07            0                           0          0              0
# 2021-02-14            0                           0          0              0
# 2021-02-21            0                           0          0              0
# 2021-02-28            0                           0          0              0
# 2021-03-07            0                           0          0              0
# 2021-03-14            0                           0          0              0
# ...

# %%
ax=Qista21.plot(figsize=(20,10))
plt.title(label="Occurrence de 'Qista' dans les recherches 2021",
          fontsize=40,
          color="Blue")
plt.xlabel('Mois 2021')
plt.ylabel('Mesures')
# Out:
# Text(0, 0.5, 'Mesures')

# %%
QistaOccitanie=pd.read_csv('Data/QistaOcci20.csv')

# %%
QistaAquitaine=pd.read_csv('Data/QistaAqui20.csv')

# %%
QistaIDF=pd.read_csv('Data/QistaIDF20.csv')

# %%
QistaPACA=pd.read_csv('Data/QistaPACA20.csv')

# %%
QistaRA=pd.read_csv('Data/QistaRA20.csv')

# %%
Qista20=pd.merge(QistaRA,QistaPACA, on='Semaine')

# %%
Qista20=pd.merge(Qista20,QistaAquitaine, on='Semaine')

# %%
Qista20=pd.merge(Qista20,QistaIDF, on='Semaine')

# %%
Qista20=pd.merge(Qista20,QistaOccitanie, on='Semaine')

# %%
Qista20.rename(columns={'Semaine': 'Date'}, inplace=True)
Qista20
# Out:
#           Date  Rhone-Alpes  Provence-Alpes-Cote d'Azur  Aquitaine  \
# 0   2020-01-05            0                           0          0
# 1   2020-01-12            0                           0          0
# 2   2020-01-19            0                           0          0
# 3   2020-01-26            0                           0          0
# 4   2020-02-02            0                           0          0
# 5   2020-02-09            0                           0          0
# 6   2020-02-16            0                           0          0
# 7   2020-02-23            0                           0          0
# 8   2020-03-01            0                           0         56
# 9   2020-03-08            0                           0          0
# 10  2020-03-15            0                           0          0
# 11  2020-03-22            0                           0          0
# 12  2020-03-29            0                           0          0
# ...

# %%
Qista20['Date'].apply(lambda x: x.replace('-',' ').replace(' ',' ')).astype('datetime64')
Qista20
# Out:
#           Date  Rhone-Alpes  Provence-Alpes-Cote d'Azur  Aquitaine  \
# 0   2020-01-05            0                           0          0
# 1   2020-01-12            0                           0          0
# 2   2020-01-19            0                           0          0
# 3   2020-01-26            0                           0          0
# 4   2020-02-02            0                           0          0
# 5   2020-02-09            0                           0          0
# 6   2020-02-16            0                           0          0
# 7   2020-02-23            0                           0          0
# 8   2020-03-01            0                           0         56
# 9   2020-03-08            0                           0          0
# 10  2020-03-15            0                           0          0
# 11  2020-03-22            0                           0          0
# 12  2020-03-29            0                           0          0
# ...

# %%
#Qista20['Date']=pd.DatetimeIndex(Qista20['Date']).month

# %%
Qista20= Qista20.groupby('Date').sum()
Qista20
# Out:
#             Rhone-Alpes  Provence-Alpes-Cote d'Azur  Aquitaine  Ile-de-France  \
# Date
# 2020-01-05            0                           0          0              0
# 2020-01-12            0                           0          0             32
# 2020-01-19            0                           0          0              0
# 2020-01-26            0                           0          0              0
# 2020-02-02            0                           0          0              0
# 2020-02-09            0                           0          0              0
# 2020-02-16            0                           0          0              0
# 2020-02-23            0                           0          0              0
# 2020-03-01            0                           0         56              0
# 2020-03-08            0                           0          0              0
# 2020-03-15            0                           0          0              0
# ...

# %%
#ax=Qista20.plot(figsize=(20,10))
#plt.title(label="Occurrence de 'Qista' dans les recherches 2020",
          #fontsize=40,
          #color="Blue")
#plt.xlabel('Mois 2020')
#plt.ylabel('Mesures')

# %%
dataqista21 = Qista21.reset_index()
Qista21 = dataqista21.melt(id_vars=["Date"],
               var_name="Region",
              value_name="occurrence du mot Qista21")

# %%
Qista21
# Out:
#            Date       Region  occurrence du mot Qista21
# 0    2021-01-03  Rhone-Alpes                         30
# 1    2021-01-10  Rhone-Alpes                          0
# 2    2021-01-17  Rhone-Alpes                          0
# 3    2021-01-24  Rhone-Alpes                          0
# 4    2021-01-31  Rhone-Alpes                          0
# ..          ...          ...                        ...
# 255  2021-11-28    Aquitaine                          0
# 256  2021-12-05    Aquitaine                          0
# 257  2021-12-12    Aquitaine                          0
# 258  2021-12-19    Aquitaine                          0
# 259  2021-12-26    Aquitaine                          0
#
# [260 rows x 3 columns]

# %%
import os 
os.makedirs('Data', exist_ok=True)
Qista21.to_csv('Data/Qista21.csv')
